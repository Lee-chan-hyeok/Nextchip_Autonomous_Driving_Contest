# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
csv_list = [
            '1.4_P2_Bt/v8s_P2_tv',
            '1.4_P2_Bt/v8s_P2_1321_tv',
            '1.4_P2_Bt/v8s_P2_2221_tv',
            
            ]

method_graph.acc_graph_by_csv_list(csv_list)
method_graph.size_acc_graph_by_csv_list(csv_list)
# Out:
# ['all', 52.6, 12.99, 34.97, 50.48]
# ['all', 52.69, 10.83, 33.47, 50.61]
# ['all', 55.58, 14.17, 39.35, 55.32]
# ['per', 26.28, 3.04, 16.68, 31.04]
# ['per', 26.0, 1.08, 13.09, 30.04]
# ['per', 30.46, 3.55, 22.06, 37.3]
# ['car', 70.49, 25.97, 54.44, 69.02]
# ['car', 70.85, 23.43, 53.31, 70.63]
# ['car', 73.77, 28.44, 60.42, 74.98]
# ['bus', 51.25, 5.33, 25.57, 37.57]
# ['bus', 53.33, 6.22, 32.15, 38.67]
# ['bus', 52.53, 7.11, 26.08, 39.78]
# ['tru', 53.05, 9.07, 28.13, 39.91]
# ['tru', 51.2, 4.25, 26.28, 31.07]
# ['tru', 50.32, 3.4, 23.0, 31.75]
# ['cyc', 12.69, 4.17, 2.01, 10.0]
# ['cyc', 7.74, 4.17, 1.01, 7.14]
# ['cyc', 9.23, 4.17, 1.51, 8.57]
# ['mot', 28.54, 1.72, 9.93, 15.27]
# ['mot', 29.36, 2.41, 11.35, 18.16]
# ['mot', 31.53, 3.44, 10.4, 19.31]
