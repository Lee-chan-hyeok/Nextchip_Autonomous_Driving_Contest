# %%
# a = method_analysys.make_size_Acc_by_cls('1.4_P2_Bt', 'v8s_P2_tv', obj_num= 4)
# for item in a:
#     print(item)

# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
csv_list = [
            # '1.4_P2_Bt/v8s_P2_tv',
            # '1.4_P2_Bt/v8s_P2_2221_tv',
            # '1.4_P2_Bt/v8s_P2_3221_tv',
            # '1.4_P2_Bt/v8s_P2_4221_tv',
            
            # "1.4_P2_Bt/v8s_P2_tv",
            # "1.4_P2_Bt/v8s_P2_1321_tv",
            # "1.4_P2_Bt/v8s_P2_3221_tv",
            # "1.4_P2_Bt/v8s_P2_3321_tv",
            
            '1.4_P2_Bt/v8s_P2_tv',
            '1.4_P2_Bt/v8s_P2_2221_tv',
            '1.4_P2_Bt/v8s_P2_3321_tv',
            
            ]

# method_graph.acc_graph_by_csv_list(csv_list)
# plt.figure(figsize=(4, 5))
method_graph.size_acc_graph_by_csv_list(csv_list, 2)
