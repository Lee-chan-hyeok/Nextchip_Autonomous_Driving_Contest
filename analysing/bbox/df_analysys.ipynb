# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# # global
# cls_dict = {0: 'per',
#             1: 'car',
#             2: 'bus',
#             3: 'tru',
#             4: 'cyc',
#             5: 'mot'}

# %%
csv_list = [
            # '1.4_P2_Bt/v8s_org_tv',
            # '1.4_P2_Bt/v8s_P2_tv',
            '1.4_P2_Bt/v8s_P2_2221_tv',
            # '1.4_P2_Bt/v8s_P2_3221_tv',
            # '1.4_P2_Bt/v8s_P2_4221_tv',
            # '3.2_neck/v8s_P2_2221_D232_tv',
            # '3.2_neck/v8s_P2_2221_D342_tv',
            '3.2_neck/v8s_P2_2221_N gc c3g_D0_tv',
            '3.2_neck/v8s_P2_2221_N gc c3g_D1_tv',
            # '3.2_neck/v8s_P2_lotto_tv',

            # '1.3_Bt/v5n_1111_ta',
            # '1.3_Bt/v5n_1221_ta',
            # '1.3_Bt/v5n_2222_ta',
            # '1.3_Bt/v5n_2332_ta',
            # '1.3_Bt/v8n_1111_ta',
            # '1.3_Bt/v8n_1221_ta',
            # '1.3_Bt/v8n_2222_ta',
            # '1.3_Bt/v8n_2332_ta',
            ]
plt.figure(figsize=(10, 5))
method_graph.acc_graph_by_csv_list(csv_list, 0.5)
plt.figure(figsize=(10, 5))
method_graph.size_acc_graph_by_csv_list(csv_list, 0.5)
