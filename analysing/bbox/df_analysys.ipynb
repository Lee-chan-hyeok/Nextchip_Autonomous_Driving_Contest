# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
csv_list = [r'sample\v5n_org_BC',
            r'sample\v8s_ghost_c3ghost_100ep_2',
            r'sample\v8s_org_100ep_2']

# %%
method_analysys.compare_Acc_by_class(csv_list)

# %%
csv_path = r'..\..\result\data_result'
df_a = pd.read_csv(f'{csv_path}\{csv_list[0]}.csv')
method_analysys.find_acc_by_cls_and_size(df_a, '_')

# %%
train = pd.read_csv('valid_set.csv')
method_analysys.find_ratio_by_cls_and_size(train, 'Train')
# Out:
# c:\Users\ihman\Desktop\NextChip\Minions_git\analysing\bbox\method_analysys.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bar1 = len(class_df[df['size'] < section[0]])
# c:\Users\ihman\Desktop\NextChip\Minions_git\analysing\bbox\method_analysys.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bar1 = len(class_df[df['size'] < section[0]])
# c:\Users\ihman\Desktop\NextChip\Minions_git\analysing\bbox\method_analysys.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bar1 = len(class_df[df['size'] < section[0]])
# c:\Users\ihman\Desktop\NextChip\Minions_git\analysing\bbox\method_analysys.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bar1 = len(class_df[df['size'] < section[0]])
# c:\Users\ihman\Desktop\NextChip\Minions_git\analysing\bbox\method_analysys.py:92: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...
