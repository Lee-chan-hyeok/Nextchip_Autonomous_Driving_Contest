# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
x, y1 = method_analysys.make_Detect_Acc('v5n_org_100b', 'v5n', show= True)
_, y2 = method_analysys.make_Detect_Acc('v8n_org_100b', 'v8n', show= False)
# Out:
# [50.54, 22.59, 71.56, 36.84, 41.82, 7.91, 28.05]
# [55.53, 32.95, 74.72, 35.1, 45.75, 4.28, 31.0]

# %%
x, y1 = method_analysys.make_Detect_Acc('v8s_ghost_c3ghost_100ep_2', 'v8s_P2G', show= True)
# Out:
# [60.64, 38.29, 78.34, 51.44, 53.8, 9.06, 35.22]

# %%
x, y2 = method_analysys.make_Detect_Acc('v8s_org_train', 'v8s_org', show= True)
# Out:
# [60.88, 37.56, 79.79, 51.32, 50.26, 10.38, 32.96]

# %%
method_analysys.make_compare_graph(x, y1, y2, 'Class', 'Acc (%)', 'Detect_Acc(%) by class')

# %%
folder_name = ''
pred_label_dir = rf'C:\Users\Ino\Desktop\NextChip\eval_result'
csv_path = r'C:\Users\Ino\Desktop\NextChip\Minions_git\result\data_result'

# %%
train_df = pd.read_csv(rf'{csv_path}\train_set.csv', index_col= 0)
test_df = pd.read_csv(rf'{csv_path}\test_set.csv', index_col= 0)
v5n_org_df = pd.read_csv(rf'{csv_path}\v5n_org_100b.csv', index_col= 0)
v8n_org_df = pd.read_csv(rf'{csv_path}\v8n_org_100b.csv', index_col= 0)

m_df = pd.read_csv(rf'{csv_path}\v8s_ghost_c3ghost_100ep_2.csv', index_col= 0)
v8s_org_df = pd.read_csv(rf'{csv_path}\v8s_org_train.csv', index_col= 0)
# display(v5n_org_df)
# display(v8n_org_df)

# %%
v5n_size_acc_list = method_analysys.find_acc_by_cls_and_size(v5n_org_df, 'Detect')
for item in v5n_size_acc_list:
    print(item)

print('----------------------------------')

v8n_size_acc_list = method_analysys.find_acc_by_cls_and_size(v8n_org_df, 'Detect')
for item in v8n_size_acc_list:
    print(item)

m_df_size_acc_list = method_analysys.find_acc_by_cls_and_size(m_df, 'Detect')
v8s_org_df_size_acc_list = method_analysys.find_acc_by_cls_and_size(v8s_org_df, 'Detect')
# Out:
# ['per', 4.18, 25.49, 42.52, 41.67, 41.67]
# ['car', 40.24, 67.07, 80.92, 90.29, 90.29]
# ['bus', 0.84, 12.78, 43.88, 64.36, 64.36]
# ['tru', 3.73, 19.66, 52.86, 73.57, 73.57]
# ['cyc', 2.22, 1.17, 14.52, 14.06, 14.06]
# ['mot', 4.5, 14.1, 32.45, 55.21, 55.21]
# ----------------------------------
# ['per', 9.46, 35.66, 57.97, 60.77, 60.77]
# ['car', 43.31, 70.45, 84.01, 93.43, 93.43]
# ['bus', 0.84, 9.32, 41.28, 64.01, 64.01]
# ['tru', 4.71, 21.6, 57.88, 79.98, 79.98]
# ['cyc', 4.44, 1.95, 2.49, 20.31, 20.31]
# ['mot', 3.5, 14.53, 34.83, 64.62, 64.62]

# %%
x_size = ['small_s', 'small_m', 'small_l', 'medium', 'large']
for idx in range(6):
    x = ['per', 'car', 'bus', 'tru', 'cyc', 'mot']
    method_analysys.make_compare_graph(x_size, m_df_size_acc_list[idx][1:], v8s_org_df_size_acc_list[idx][1:], 'Class', 'Acc (%)', f'{x[idx]}_Detect_Acc by size')

# %%
x_size = ['small_s', 'small_m', 'small_l', 'medium', 'large']
for idx in range(6):
    x = ['per', 'car', 'bus', 'tru', 'cyc', 'mot']
    method_analysys.make_compare_graph(x_size, v5n_size_acc_list[idx][1:], v8n_size_acc_list[idx][1:], 'Class', 'Acc (%)', f'{x[idx]}_Detect_Acc by size')
