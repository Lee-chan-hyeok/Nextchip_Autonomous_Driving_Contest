# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
# path = '../../result/data_result/1.1_v5n_vs_v8n/'
# cat = '1.1_v5n_vs_v8n'
# name_list = os.listdir(path)
# name_list = [item[:-4] for item in name_list]

# print(name_list)

# x, y0 = method_analysys.make_Detect_Acc_by_class(cat, name_list[0], show= False)
# x, y1 = method_analysys.make_Detect_Acc_by_class(cat, name_list[2], show= False)
# x, y2 = method_analysys.make_Detect_Acc_by_class(cat, name_list[3], show= False)

# method_graph.compare_graph(x, [y0, y1, y2], name_list)

csv_list = ['1.1_v5n_vs_v8n/v5n_k3_tv',
            '1.1_v5n_vs_v8n/v8n_c3_tv',
            '1.1_v5n_vs_v8n/v8n_org_tv',
            ]

method_graph.size_acc_graph_by_csv_list(csv_list)

# %%
# x, y0 = method_analysys.make_size_Acc_by_cls(cat, name_list[0], show= False)
# _, y1 = method_analysys.make_size_Acc_by_cls(cat, name_list[1], show= False)
# _, y2 = method_analysys.make_size_Acc_by_cls(cat, name_list[2], show= False)

# # print(y0)

# for i in range(7):
#     method_graph.compare_graph(x, [y0[i][1:], y1[i][1:], y2[i][1:]], name_list[:3])

# method_analysys.make_size_Acc_by_cls('1.1_v5n_vs_v8n', 'v5n_k3_tv')
