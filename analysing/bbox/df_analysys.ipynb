# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
csv_list = [
            '2.1_QE/v5n_2442_ta',
            '2.1_QE/v5n_4664_ta',
            '2.1_QE/v5n_6886_ta',
            '2.1_QE/v8s_P2_3963_ta',
            '2.1_QE/v8s_P2_9963_ta',
            # '2.1_QE/',
            ]

method_graph.acc_graph_by_csv_list(csv_list, 0.5)
method_graph.size_acc_graph_by_csv_list(csv_list, 0.5)
