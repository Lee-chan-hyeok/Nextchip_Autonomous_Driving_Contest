# %%
import method_analysys
import pandas as pd
import warnings
import matplotlib.pyplot as plt

# UserWarning을 무시
warnings.filterwarnings("ignore", category=UserWarning)

# %%
test_df = pd.read_csv(rf'test_set.csv', index_col= 0)
train_df = pd.read_csv(rf'train_set.csv', index_col= 0)
valid_df = pd.read_csv(rf'valid_set.csv', index_col= 0)

# %%
plt.figure(figsize = (6, 5))
plt.ylim([0, 65])
method_analysys.ratio_by_cls(train_df, 'Train set', 'Ratio', show= True)

plt.figure(figsize = (6, 5))
plt.ylim([0, 65])
method_analysys.ratio_by_cls(valid_df, 'Valid set', 'Ratio', show= True)

plt.figure(figsize = (6, 5))
plt.ylim([0, 65])
a = method_analysys.ratio_by_cls(test_df, 'Test set','Ratio', show= True)
print(a)
# Out:
# [29.52, 52.95, 5.28, 6.15, 1.21, 4.88]

# %%
plt.figure(figsize=(6, 5))
plt.ylim([0, 65])
a = method_analysys.size_ratio_by_cls(test_df, 'Test set', 'Ratio', obj_num=4)
print(a)
# Out:
# [['', 50.03, 26.42, 23.55], ['per', 66.05, 23.05, 10.9], ['car', 44.02, 26.83, 29.16], ['bus', 37.14, 29.84, 33.02], ['tru', 41.59, 28.67, 29.74], ['cyc', 48.27, 41.02, 10.71], ['mot', 43.45, 32.23, 24.32]]

# %%
# method_analysys.find_size_ratio_by_cls(train_df, 'Train set', 'Ratio')

# %%
# method_analysys.find_size_ratio_by_cls(valid_df, 'Valid set', 'Ratio')
