# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
csv_list = [
            # '1.1_v5n_vs_v8n/v5n_c2f_tv',
            # '1.1_v5n_vs_v8n/v5n_k3_tv',
            # '1.1_v5n_vs_v8n/v5n_org_tv',
            # '1.1_v5n_vs_v8n/v8n_c3_tv',
            '1.1_v5n_vs_v8n/v8n_k6_tv',
            '1.1_v5n_vs_v8n/v8n_org_tv',
            ]

# method_graph.acc_graph_by_csv_list(csv_list)
method_graph.size_acc_graph_by_csv_list(csv_list, obj_num= 3)
# Out:
# ['all', 44.53, 9.99, 25.19, 38.76]
# ['all', 47.25, 10.13, 27.85, 43.45]
# ['per', 17.12, 0.61, 6.33, 18.91]
# ['per', 20.19, 0.66, 7.24, 21.91]
# ['car', 63.57, 22.68, 44.96, 58.2]
# ['car', 68.3, 23.1, 51.71, 66.12]
# ['bus', 45.05, 2.22, 14.43, 26.8]
# ['bus', 33.51, 0.44, 5.57, 19.89]
# ['tru', 38.57, 0.57, 14.17, 17.46]
# ['tru', 38.38, 0.28, 8.21, 18.14]
# ['cyc', 2.14, 4.17, 0.5, 1.43]
# ['cyc', 2.47, 0.0, 1.01, 1.43]
# ['mot', 21.21, 0.0, 3.31, 8.65]
# ['mot', 19.66, 0.0, 2.13, 8.07]
