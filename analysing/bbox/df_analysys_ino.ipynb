# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
csv_list = [
        '1.1_v5n_vs_v8n/v5n_org_tv',
        '1.1_v5n_vs_v8n/v8n_org_tv',
            ]

# method_graph.acc_graph_by_csv_list(csv_list)
method_graph.size_acc_graph_by_csv_list(csv_list, obj_num= 4, conf= 0.5)

# %%
csv_list = [
        '1.4_P2_Bt/v8s_P2_tv',
        '1.4_P2_Bt/v8s_P2_1321_tv',
        # '1.4_P2_Bt/v8s_P2_2221_tv',
        '1.4_P2_Bt/v8s_P2_3221_tv',
        '1.4_P2_Bt/v8s_P2_3321_tv',
        # '1.4_P2_Bt/v8s_P2_4221_tv',
            ]

# method_graph.acc_graph_by_csv_list(csv_list)
method_graph.size_acc_graph_by_csv_list(csv_list, obj_num= 4, conf= 0.5)

# %%
csv_list = [
        '1.4_P2_Bt/v8s_org_tv',
        '1.4_P2_Bt/v8s_P2_tv',
        '1.4_P2_Bt/v8s_P2_2221_tv',
        # 'final/v8s_P2_2221_gc-c3g_tv',
        'final/v8s_P2_2211_gc-c3g_tv',
            ]

# method_graph.acc_graph_by_csv_list(csv_list)
method_graph.size_acc_graph_by_csv_list(csv_list, obj_num= 4, conf= 0.25)
