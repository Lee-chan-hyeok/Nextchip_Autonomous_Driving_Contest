# %%
import os
import pandas as pd
import method_dataframe
import method_draw
import method_graph
import method_analysys
import mAP

# %%
# Example usage
pred_dir = "../../../v8s_P2_2221_tv"  # Directory containing prediction TXT files
gt_dir = "../../../test"  # Directory containing ground truth TXT files

mAP50_by_size = mAP.process_all_files(pred_dir, gt_dir)
print("mAP@50 by size:", mAP50_by_size)
# Out:
# c:\Users\ihman\anaconda3\envs\DL\lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\ihman\anaconda3\envs\DL\lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\ihman\anaconda3\envs\DL\lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\ihman\anaconda3\envs\DL\lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\ihman\anaconda3\envs\DL\lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# ...
