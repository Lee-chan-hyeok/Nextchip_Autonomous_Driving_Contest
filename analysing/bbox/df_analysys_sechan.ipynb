# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
csv_list = [
            # '1.1_v5n_vs_v8n/v5n_c2f_tv',
            # '1.1_v5n_vs_v8n/v5n_org_tv',
            # '1.1_v5n_vs_v8n/v5n_k3_tv',
            # '1.1_v5n_vs_v8n/v8n_k6_tv',
            # '1.1_v5n_vs_v8n/v8n_org_tv',
            # '1.1_v5n_vs_v8n/v8n_c3_tv',
                '1.4_P2_Bt/v8s_P2_tv',
                '2.2_sP2_c2f_c3_c3g/sP2_B8 c c2f_N8 SF c c3_tv',
                '2.2_sP2_c2f_c3_c3g/sP2_B8 c c2f_N8 SF c c3g_tv',
                '2.2_sP2_c2f_c3_c3g/sP2_B8 c c2f_N8 SF gc c2f_tv',
                '2.2_sP2_c2f_c3_c3g/sP2_B8 c c2f_N8 SF gc c3_tv',
                '2.2_sP2_c2f_c3_c3g/sP2_B8 c c2f_N8 SF gc c3g_tv',

            ]

method_graph.acc_graph_by_csv_list(csv_list)
method_graph.size_acc_graph_by_csv_list(csv_list, obj_num= 4)
