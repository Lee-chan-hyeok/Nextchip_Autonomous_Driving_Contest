# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
csv_list = [
            '1.2_P2/v8s_org_t',
            '1.2_P2/v8s_P2_t',
            # '1.3_Bt/v5n_6886_ta',
            # '2.1_QE/v8n_b5n8_4664_ta',
            # '2.1_QE/v8n_b5n8_6886_ta',

            # '1.3_Bt/v8n_2442_ta',
            # '1.3_Bt/v8n_4664_ta',
            # '1.3_Bt/v8n_6886_ta',
            # '2.1_QE/v5n_b8n5_4664_ta',
            # '2.1_QE/v5n_b8n5_6886_ta',

            # '1.2_P2/v8n_P2_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-c-c3_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-c-c3g_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-gc-c2f_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-gc-c3_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-gc-c3g_t',
            
            # '1.4_P2_Bt/v8s_P2_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-c-c3_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-c-c3g_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-gc-c2f_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-gc-c3_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-gc-c3g_tv',
            
            ]

method_graph.acc_graph_by_csv_list(csv_list, 0.5)
method_graph.size_acc_graph_by_csv_list(csv_list, 0.5)
# Out:
# obj_num은 3이나 5야 멍청아
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 31
#       1 csv_list = [
#       2             '1.2_P2/v8s_org_t',
#       3             '1.2_P2/v8s_P2_t',
#    (...)
#      27
#      28             ]
#      30 method_graph.acc_graph_by_csv_list(csv_list, 0.5)
# ---> 31 method_graph.size_acc_graph_by_csv_list(csv_list, 0.5)
#
# File c:\Users\user\Nextchip\JARVIS\Minions\analysing\bbox\method_graph.py:94, in size_acc_graph_by_csv_list(csv_list, obj_num, conf)
#      91     cat, name = csv.split('/')[-2:]
#      92     name_list.append(name)
# ---> 94     x, y = method_analysys.make_size_Acc_by_cls(cat, name, conf= conf, obj_num= obj_num)
#      95     y_list.append(y[i][1:])
#      97 # name에서 _tv등등 제거
#
# File c:\Users\user\Nextchip\JARVIS\Minions\analysing\bbox\method_analysys.py:226, in make_size_Acc_by_cls(category, exp_name, conf, obj_num, graph_name, show)
#     223 else:
#     224     print('obj_num은 3이나 5야 멍청아')
# --> 226 y_list = find_acc_by_cls_and_size(result_df, obj_num= obj_num)
#     228 for y in y_list:
#     229     if(show == True):
#
# File c:\Users\user\Nextchip\JARVIS\Minions\analysing\bbox\method_analysys.py:110, in find_acc_by_cls_and_size(df, dt_condition, obj_num)
#     107 size_acc_list = []
#     109 # 전체에 대해 사이즈별 정확도
# --> 110 size_acc_list.append(['all', *find_acc_by_size(df, 'all', section= section)])
#     112 # 클래스별로 사이즈별 정확도
#     113 for cls in cls_list:
#
# UnboundLocalError: cannot access local variable 'section' where it is not associated with a value
