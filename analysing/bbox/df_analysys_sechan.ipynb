# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
# csv_list만 넣어주면 클래스별로 박스 사이즈 정확도 그래프 생성

csv_list = ['1.4_P2_Bt/v8s_org_tv',
            '1.4_P2_Bt/v8s_P2_9963_tv',
            ]

method_graph.size_acc_graph_by_csv_list(csv_list)

# %%
csv_list = ['1.4_P2_Bt/v8s_org_tv',
            '1.4_P2_Bt/v8s_P2_tv',
            ]

method_graph.acc_graph_by_csv_list(csv_list)
