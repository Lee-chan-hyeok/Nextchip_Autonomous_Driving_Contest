# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas as pd

# %%
import method_dataframe
import method_graph
import method_draw
import method_analysys

# %%
# global
cls_dict = {0: 'per',
            1: 'car',
            2: 'bus',
            3: 'tru',
            4: 'cyc',
            5: 'mot'}

# %%
csv_list = [
            '1.2_P2/v8s_org_t',
            '1.2_P2/v8s_P2_t',
            # '1.3_Bt/v5n_6886_ta',
            # '2.1_QE/v8n_b5n8_4664_ta',
            # '2.1_QE/v8n_b5n8_6886_ta',

            # '1.3_Bt/v8n_2442_ta',
            # '1.3_Bt/v8n_4664_ta',
            # '1.3_Bt/v8n_6886_ta',
            # '2.1_QE/v5n_b8n5_4664_ta',
            # '2.1_QE/v5n_b8n5_6886_ta',

            # '1.2_P2/v8n_P2_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-c-c3_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-c-c3g_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-gc-c2f_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-gc-c3_t',
            # '2.2_nP2_c2f_c3_c3g/nP2_B8-c-c2f_N8-SF-gc-c3g_t',
            
            # '1.4_P2_Bt/v8s_P2_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-c-c3_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-c-c3g_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-gc-c2f_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-gc-c3_tv',
            # '2.2_sP2_c2f_c3_c3g/sP2_B8-c-c2f_N8-SF-gc-c3g_tv',
            
            ]

method_graph.acc_graph_by_csv_list(csv_list, 0.5)
method_graph.size_acc_graph_by_csv_list(csv_list, 0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 31
#       1 csv_list = [
#       2             '1.2_P2/v8s_org_t',
#       3             '1.2_P2/v8s_P2_t',
#    (...)
#      27
#      28             ]
#      30 method_graph.acc_graph_by_csv_list(csv_list, 0.5)
# ---> 31 method_graph.size_acc_graph_by_csv_list(csv_list, 0.5)
#
# File c:\Users\ihman\Desktop\NextChip\Minions_git\analysing\bbox\method_graph.py:102, in size_acc_graph_by_csv_list(csv_list, conf)
#      99 data = name_list[0].split('_')[-1]
#     100 name_list = [item.replace(f'_{data}', '') for item in name_list]
# --> 102 compare_graph(x, y_list, name_list, x_title= 'Object size', title= f'Acc by size [{y[i][0]}]')
#
# File c:\Users\ihman\Desktop\NextChip\Minions_git\analysing\bbox\method_graph.py:53, in compare_graph(x_ticks, y_data, labels, x_title, y_title, title)
#      51 # 그래프 그리기
# ...
