# %%
import method_analysys
import pandas as pd
import warnings

# UserWarning을 무시
warnings.filterwarnings("ignore", category=UserWarning)

# %%
csv_path = r'C:\Users\Ino\Desktop\NextChip\Minions_git\result\data_result'
train_df = pd.read_csv(rf'{csv_path}\train_set.csv', index_col= 0)

# %%
method_analysys.find_ratio_by_cls_and_size(train_df, 'Train set', 'Num')
# Out:
# [['per', 23.3536, 17.1851, 16.7823, 27.0371, 15.6418],
#  ['car', 13.2474, 15.0077, 14.0196, 27.2141, 30.5112],
#  ['bus', 7.8279, 9.2736, 13.6812, 29.1608, 40.0564],
#  ['tru', 8.1547, 10.8108, 13.0631, 27.0115, 40.9599],
#  ['cyc', 10.8154, 17.9582, 22.9111, 33.7264, 14.5889],
#  ['mot', 14.9277, 12.225, 15.6191, 29.7926, 27.4356]]
