# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
        # 'v5n_c2f_tv',
        # 'v5n_k3_tv',
        # 'v5n_org_tv',
        # 'v8n_c3_tv',
        # 'v8n_k6_tv',
        # 'v8n_org_tv',
            ]

labels = [
        # 'N_mAP / G_mAP (%)',
        'N_mAP', 
        'G_mAP',
        # 'params',
        # 'FPS',
        ]

# plt.figure(figsize=())
# excel_tool.exp_graph('model', '%', '', name_list, [0, 3], labels)

# %%
name_list = [
        'v8s_P2_tv',
        'sP2_B8 c c2f_N8 SF c c3_tv',
        'sP2_B8 c c2f_N8 SF c c3g_tv',
        'sP2_B8 c c2f_N8 SF gc c2f_tv',
        'sP2_B8 c c2f_N8 SF gc c3_tv',
        'sP2_B8 c c2f_N8 SF gc c3g_tv',
            ]

labels = [
        'N_mAP / G_mAP (%)',
        'N_mAP', 
        'G_mAP',
        # 'params',
        # 'FPS',
        ]

# plt.figure(figsize=())
# excel_tool.exp_graph('model', '%', '', name_list, [0, 3], labels)
excel_tool.exp_graph_modified('model', '%', '', name_list, [-2, -1], labels, y_lim= [40, 75])
