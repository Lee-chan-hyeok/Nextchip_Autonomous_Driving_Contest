# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
        # 'v5n_c2f_tv',
        # 'v5n_k3_tv',
        # 'v5n_org_tv',
        # 'v8n_c3_tv',
        'v8n_k6_tv',
        'v8n_org_tv',
            ]

labels = [
        # 'N_mAP / G_mAP (%)',
        'N_mAP', 
        'G_mAP',
        # 'params',
        'FPS',
        ]

# plt.figure(figsize=())
excel_tool.exp_graph('model', '%', '', name_list, [0, 3], labels, y_lim=[35, 70])
