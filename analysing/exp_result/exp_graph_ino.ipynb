# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
        'v8s_org_tv',
        # 'v8s_P2_tv',
        # 'v8s_P2_2221_tv',
        # 'v8s_P2_2221_gc-c3g_tv',
        'v8s_P2_2211_gc-c3g_tv',
            ]

labels = [
        'N_mAP / G_mAP (%)',
        # 'N_mAP', 
        # 'G_mAP',
        # 'params',
        # 'FPS',
        ]

# excel_tool.exp_graph('model', '%', '', name_list, [0, 3], labels)

plt.figure(figsize=(6, 6))
excel_tool.exp_graph_modified('',
                              '%',
                              '',
                              name_list,
                              [0, -2],
                              labels= labels,
                              y_lim=[0, 80],
                              )
