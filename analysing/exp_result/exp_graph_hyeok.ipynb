# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
        # "v8s_P2_tv",
        # "v8s_P2_N c c3_tv",
        # "v8s_P2_N c c3g_tv",
        # "v8s_P2_N gc c2f_tv",
        # "v8s_P2_N gc c3_tv",
        # "v8s_P2_N gc c3g_tv",
        
        "v8s_P2_tv",
        "v8s_P2_1321_tv",
        "v8s_P2_3221_tv",
        "v8s_P2_3321_tv",
]

labels = [
        # 'N_mAP / G_mAP (%)',
        # 'G_mAP',
        'N_mAP', 
        # 'params',
        # 'FPS',
        ]

# plt.figure(figsize=(12, 5))
excel_tool.exp_graph_modified('', '%', 'v8s_P2', name_list, [0, -2], labels, y_lim=[0, 50])

# %%
# name_list = [
#         'v8s_P2_tv',
#         'v8s_P2_1321_tv',
#         'v8s_P2_2221_tv',
#         'v8s_P2_3221_tv',
#         'v8s_P2_3321_tv',
#         'v8s_P2_4221_tv',
#             ]

# labels = [
#         # 'N_mAP / G_mAP (%)',
#         'N_mAP', 
#         # 'G_mAP',
#         # 'params',
#         # 'FPS',
#         ]

# plt.figure(figsize=(10, 5))
# excel_tool.exp_graph('model', '%', 'org vs P2', name_list, [0, 2], labels, y_lim=[40, 55])
