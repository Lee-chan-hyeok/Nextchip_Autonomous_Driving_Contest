# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
        'nP2_B8 c c2f_N8 SF c c3g_t',
        'nP2_B8 c c2f_N8 SF c c3_t',
        'nP2_B8 c c2f_N8 SF gc c2f_t',

        # 'v8s_org_t',
        # 'v8s_P2_t',
        # 'v8n_org_t',
        # 'v8n_P2_t',
            ]

labels = [
        'N_mAP / G_mAP (%)',
        'N_mAP', 
        'G_mAP',
        'params',
        'FPS',
        ]

excel_tool.exp_graph('model', '%', 'org vs P2', name_list, [1, 3], labels)
