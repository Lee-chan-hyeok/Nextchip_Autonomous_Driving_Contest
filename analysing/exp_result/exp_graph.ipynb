# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
            # 'v8s_org_tv',
            # 'v8s_P2_tv',
            # 'v8s_P2_1321_tv',
            # 'v8s_P2_2221_tv',
            # 'v8s_P2_4221_tv',
            # 'v8s_P2_3221_tv',
            # 'v8s_P2_3321_tv',
            ]
# excel_tool.exp_graph(name_list, 'Model', '%', 'percent by s_Model', [40, 60])

# %%
name_list = [
            'v5n_1111_ta',
            'v5n_1221_ta',
            'v5n_2222_ta',
            'v5n_2332_ta',
            'v8n_1111_ta',
            'v8n_1221_ta',
            'v8n_2222_ta',
            'v8n_2332_ta',
            ]
plt.figure(figsize= (10, 5))
excel_tool.exp_graph(name_list, 'Model', '%', 'percent by Model')

# %%
name_list = [
            'v8s_P2_tv',
            'sP2_B8 c c2f_N8 SF c c3_tv',
            'sP2_B8 c c2f_N8 SF c c3g_tv',
            'sP2_B8 c c2f_N8 SF gc c2f_tv',
            'sP2_B8 c c2f_N8 SF gc c3_tv',
            'sP2_B8 c c2f_N8 SF gc c3g_tv',            
            ]
excel_tool.exp_graph(name_list, 'Model', '%', 'percent by s_Model', [40, 60])

# %%
name_list = [
            'sP2_B8 c c2f_N8 SF gc c2f_tv',
            'sP2_B8 c c2f_N8 SF gc c3_tv',
            'sP2_B8 c c2f_N8 SF gc c3g_tv',
            ]
excel_tool.exp_graph(name_list, 'Model', '%', 'percent by Model', [40, 80])
