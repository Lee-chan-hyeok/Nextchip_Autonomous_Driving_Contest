# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
        'v5n_org_tv',
        'v5n_k3_tv'
        ]

labels = [
        # 'params',
        'G_mAP',
        'N_mAP', 
        'N_mAP / G_mAP (%)',
        # 'FPS',
        ]

# plt.figure(figsize=(12, 5))
excel_tool.exp_graph('Model', 'mAP', 'mAP by Model', name_list, labels)
