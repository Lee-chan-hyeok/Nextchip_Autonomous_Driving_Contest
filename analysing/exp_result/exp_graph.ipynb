# %%
import pandas as pd
import matplotlib.pyplot as plt
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
        'v8s_P2_tv',
        'v8s_P2_2221_tv',
        'v8s_P2_3221_tv',
        'v8s_P2_4221_tv',
            ]

labels = [
        # 'N_mAP / G_mAP (%)',
        'N_mAP', 
        'G_mAP',
        # 'params',
        # 'FPS',
        ]

excel_tool.exp_graph('a', 'b', 'c', name_list)
