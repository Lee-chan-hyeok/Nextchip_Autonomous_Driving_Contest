# %%
import pandas as pd
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
# 모델 이름 선택
name_list = ['v8n_org_t',
             'v8s_P2_t',
             'v8s_P2_tv',
             'v5n_org_t']

# %%
excel_tool.exp_graph(name_list, [0, 50])
