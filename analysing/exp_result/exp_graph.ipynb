# %%
import pandas as pd
import excel_tool

# %%
exp_list = pd.read_csv('../../documents/exp_list.csv', index_col= 0)

# %%
name_list = [
            'v5n_2442_ta',
            'v5n_4664_ta',
            'v5n_6886_ta',
            # 'v8n_b5n8_4664_ta',
            # 'v8n_b5n8_6886_ta',
            ]
excel_tool.exp_graph(name_list)

# %%
name_list = [
            'v8n_2442_ta',
            'v8n_4664_ta',
            'v8n_6886_ta',
            ]
excel_tool.exp_graph(name_list)
