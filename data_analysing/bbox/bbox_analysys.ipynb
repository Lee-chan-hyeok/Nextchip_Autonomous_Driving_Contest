# %%
import cv2
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import dataframe_method
import graph_method

# %%
# load result_df
result_df = pd.read_csv('v8n_ghostp6_100best.csv', index_col= 0)
display(result_df)
# Out:
#       file_name class  detect_tf   size iou_tf  class_tf       iou      conf
# 0      0000.txt   car      False   5544     -1        -1 -1.000000 -1.000000
# 1      0000.txt   car      False    150     -1        -1 -1.000000 -1.000000
# 2      0000.txt   car      False    140     -1        -1 -1.000000 -1.000000
# 3      0001.txt   car      False   8308     -1        -1 -1.000000 -1.000000
# 4      0001.txt   car      False    130     -1        -1 -1.000000 -1.000000
# ...         ...   ...        ...    ...    ...       ...       ...       ...
# 50062  6880.txt   car       True  18291   True         1  0.871755  0.880797
# 50063  6881.txt   car      False   2584     -1        -1 -1.000000 -1.000000
# 50064  6881.txt   car      False    816     -1        -1 -1.000000 -1.000000
# 50065  6882.txt   car      False    912     -1        -1 -1.000000 -1.000000
# 50066  6882.txt   car      False    378     -1        -1 -1.000000 -1.000000
#
# [50067 rows x 8 columns]

# %%
#display(result_df.sort_values(by= ['box_size']))

# %%
# # show size
# trues = [0.7953125, 0.4097222222222222, 0.1671875, 0.2722222222222222]
# preds = [0, 0, 0, 0]
# iou, bbox = dataframe_method.get_IoU(trues, preds)
# print('bbox size is', bbox)
# file_name = '5807.txt'

# # show Bbox
# txt_path = rf'C:\Users\Ino\Desktop\NextChip\dataset\labels\test\{file_name}'
# dataframe_method.draw_box(txt_path, 0, (1280, 720))

# %%
# box size별 정확도

# range 설정
box_range = [0, 500, 10000, 50000, 921600]
xsmall_box_range = {'min' : box_range[0], 'max' : box_range[1]}
small_box_range = {'min' : box_range[1], 'max' : box_range[2]}
medium_box_range = {'min' : box_range[2], 'max' : box_range[3]}
large_box_range = {'min' : box_range[3], 'max' : box_range[4]}

# size별로 df 필터링
xsmall_df = result_df[(xsmall_box_range['min'] <= result_df['size']) & (result_df['size'] <= xsmall_box_range['max'])]
small_df = result_df[(small_box_range['min'] <= result_df['size']) & (result_df['size'] <= small_box_range['max'])]
medium_df = result_df[(medium_box_range['min'] < result_df['size']) & (result_df['size'] <= medium_box_range['max'])]
large_df = result_df[(large_box_range['min'] < result_df['size']) & (result_df['size'] <= large_box_range['max'])]

#display(xsmall_df.sort_values(by= ['box_size']))
#display(small_df.sort_values(by= ['box_size']))
#display(medium_df.sort_values(by= ['box_size']))
#display(large_df.sort_values(by= ['box_size']))

# %%
# acc by size

acc_of_xsmall = len(xsmall_df[xsmall_df['detect_tf'] == True]) / (len(xsmall_df))
print('acc_of_x is ', round(acc_of_xsmall*100, 3), ', num of x is', len(xsmall_df))

acc_of_small = len(small_df[small_df['detect_tf'] == True]) / (len(small_df))
print('acc_of_s is ', round(acc_of_small*100, 3), ', num of s is', len(small_df))

acc_of_medium = len(medium_df[medium_df['detect_tf'] == True]) / (len(medium_df))
print('acc_of_m is', round(acc_of_medium*100, 3), ', num of m is', len(medium_df))

acc_of_large = len(large_df[large_df['detect_tf'] == True]) / (len(large_df))
print('acc_of_l is', round(acc_of_large*100, 3), ', num of l is', len(large_df))

print(len(small_df) + len(medium_df) + len(large_df))
# Out:
# acc_of_x is  0.0 , num of x is 6866
# acc_of_s is  3.072 , num of s is 19759
# acc_of_m is 92.912 , num of m is 15647
# acc_of_l is 99.516 , num of l is 7859
# 43265

# %%
# class별 정확도

# %%
# class에 따른 bix size별 정확도
