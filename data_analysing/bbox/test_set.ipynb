# %%
import method_analysys
import pandas as pd
import warnings

# UserWarning을 무시
warnings.filterwarnings("ignore", category=UserWarning)

# %%
csv_path = r'C:\Users\Ino\Desktop\NextChip\Minions_git\result\data_result'
test_df = pd.read_csv(rf'{csv_path}\test_set.csv', index_col= 0)

# %%
method_analysys.find_ratio_by_cls_and_size(test_df, 'Test set', 'Num')
# Out:
# [['per', 31.9984, 18.4955, 15.5595, 23.0483, 10.8984],
#  ['car', 15.5967, 14.3709, 14.0502, 26.8256, 29.1566],
#  ['bus', 8.5098, 14.9395, 13.6914, 29.8411, 33.0182],
#  ['tru', 11.461, 15.8117, 14.3182, 28.6688, 29.7403],
#  ['cyc', 3.9539, 32.7842, 11.5321, 41.0214, 10.7084],
#  ['mot', 11.9165, 17.3219, 14.2097, 32.2277, 24.3243]]
