# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import bbox_method
import graph_method

# %%
true_label_dir = rf'C:\Users\Ino\Desktop\NextChip\dataset\labels\test'

folder_name = 'v5_next_org'
pred_label_dir = rf'C:\Users\Ino\Desktop\NextChip\eval_result'
csv_path = r'C:\Users\Ino\Desktop\NextChip\Minions_git\data_analysing\bbox'

# %%
box_df = pd.read_csv(rf'{csv_path}\{folder_name}.csv')
display(box_df)
# Out:
#        Unnamed: 0 file_name class  detect_tf  box_size       iou      conf
# 0               0  0000.txt   car       True      5543  0.887385  0.817575
# 1               1  0000.txt   car       True       175  0.588458  0.004070
# 2               2  0000.txt   car       True       154  0.519283  0.029312
# 3               3  0001.txt   car       True      8308  0.942523  0.002473
# 4               4  0001.txt   car       True       142  0.571037  0.017986
# ...           ...       ...   ...        ...       ...       ...       ...
# 50062       50062  6880.txt   car       True     18179  0.868018  0.731059
# 50063       50063  6881.txt   car       True      2584  0.866076  0.622459
# 50064       50064  6881.txt   car       True       816  0.786148  0.182426
# 50065       50065  6882.txt   car       True       912  0.874767  0.047426
# 50066       50066  6882.txt   car      False       395  0.000000  0.000000
#
# [50067 rows x 7 columns]

# %%
# sns.displot(box_df, x= 'box_size', kind= 'kde')
# plt.xlim([0, 20000])
# plt.ylim([0, 0.0001])
# plt.show()
# print(1280*720)
# Out:
# 921600

# %%
per_df = box_df[box_df['class'] == 'per']
car_df = box_df[box_df['class'] == 'car']

# %%
# sns.displot(per_df, x= 'box_size', kind= 'kde')
# plt.xlim([0, 40000])
# plt.ylim([0, 0.0003])
# plt.show()

# %%
# plt.hist(per_df['box_size'], bins= [0, 10, 100, 1000, 10000, 20000, 400000], cumulative= False, density= False, histtype= 'barstacked')
# plt.xlim([100, 40000])
# Out:
# (array([   0.,  227., 7798., 5803.,  541.,  413.]),
#  array([0.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 2.e+04, 4.e+05]),
#  <BarContainer object of 6 artists>)

# %%
# box size별 정확도

# %%
# class별 정확도

# %%
# class에 따른 bix size별 정확도
